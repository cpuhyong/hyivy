-- %%
-- 步骤2: 保存到Silver层（Delta格式，外部表）

CREATE TABLE IF NOT EXISTS silver_orders_info
(
    id                     BIGINT,
    consignee              STRING,
    consignee_tel          STRING,
    total_amount           DECIMAL(10,2),
    order_status           STRING,
    user_id                BIGINT,
    payment_way            STRING,
    delivery_address       STRING,
    order_comment          STRING,
    out_trade_no           STRING,
    trade_body             STRING,
    create_time            TIMESTAMP,
    operate_time           TIMESTAMP,
    expire_time            TIMESTAMP,
    process_status         STRING,
    tracking_no            STRING,
    parent_order_id        BIGINT,
    img_url                STRING,
    province_id            INT,
    activity_reduce_amount DECIMAL(16,2),
    coupon_reduce_amount   DECIMAL(16,2),
    original_total_amount  DECIMAL(16,2),
    feight_fee             DECIMAL(16,2),
    feight_fee_reduce      DECIMAL(16,2),
    refundable_time        TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/order_info'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_base_category1
(
    id           bigint,
    name         STRING ,
    create_time  TIMESTAMP   ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_category1'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_base_category2
(
    id           bigint,
    name         STRING ,
    category1_id bigint,
    create_time  TIMESTAMP   ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_category2'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_base_category3
(
    id           bigint,
    name         STRING ,
    category2_id bigint,
    create_time  TIMESTAMP   ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_category3'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);


create EXTERNAL table silver_base_province
(
    id           bigint      ,
    name         STRING ,
    region_id    STRING ,
    area_code    STRING ,
    iso_code     STRING ,
    iso_3166_2   STRING ,
    create_time  TIMESTAMP    ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_province'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_base_region
(
    id           bigint ,
    region_name  STRING ,
    create_time  TIMESTAMP    ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_region'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);


create EXTERNAL table silver_order_detail
(
    id                    bigint ,
    order_id              bigint        ,
    sku_id                bigint         ,
    sku_name              STRING   ,
    img_url               STRING   ,
    order_price           decimal(10, 2),
    sku_num               bigint         ,
    create_time           TIMESTAMP       ,
    split_total_amount    decimal(16, 2) ,
    split_activity_amount decimal(16, 2) ,
    split_coupon_amount   decimal(16, 2) ,
    operate_time          TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/order_detail'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_sku_info
(
    id              bigint ,
    spu_id          bigint            ,
    price           decimal           ,
    sku_name        STRING     ,
    sku_desc        STRING     ,
    weight          decimal(10, 2)    ,
    tm_id           bigint           ,
    category3_id    bigint           ,
    sku_default_img STRING      ,
    is_sale         int ,
    create_time     TIMESTAMP          ,
    operate_time    TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/sku_info'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_spu_info
(
    id           bigint ,
    spu_name     STRING ,
    description  STRING,
    category3_id bigint       ,
    tm_id        bigint       ,
    create_time  TIMESTAMP     ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/spu_info'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_user_info
(
    id           bigint ,
    login_name   STRING ,
    nick_name    STRING ,
    passwd       STRING ,
    name         STRING ,
    phone_num    STRING ,
    email        STRING ,
    head_img     STRING ,
    user_level   STRING ,
    birthday     date         ,
    gender       STRING  ,
    create_time  TIMESTAMP     ,
    operate_time TIMESTAMP     ,
    status       STRING,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/user_info'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

create EXTERNAL table silver_base_trademark
(
    id           bigint ,
    tm_name  STRING ,
    logo_url    STRING,
    create_time  TIMESTAMP    ,
    operate_time TIMESTAMP,
    source_file            STRING,
    load_timestamp         TIMESTAMP,
    update_timestamp       TIMESTAMP
)
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/silver/gmall/base_trademark'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',
    'delta.enableChangeDataFeed' = 'true'
);

-- %%
-- 选项1: 删除所有表（注意：这会删除表和数据）
DROP TABLE IF EXISTS silver_orders_info;
DROP TABLE IF EXISTS silver_base_category1;
DROP TABLE IF EXISTS silver_base_category2;
DROP TABLE IF EXISTS silver_base_category3;
DROP TABLE IF EXISTS silver_base_province;
DROP TABLE IF EXISTS silver_base_region;
DROP TABLE IF EXISTS silver_order_detail;
DROP TABLE IF EXISTS silver_sku_info;
DROP TABLE IF EXISTS silver_spu_info;
DROP TABLE IF EXISTS silver_user_info;

-- %%
-- 选项2: 使用 ALTER TABLE 添加列（保留现有数据）

-- silver_base_category1 添加列
ALTER TABLE silver_base_category1 ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_base_category2 添加列
ALTER TABLE silver_base_category2 ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_base_category3 添加列
ALTER TABLE silver_base_category3 ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_base_province 添加列
ALTER TABLE silver_base_province ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_base_region 添加列
ALTER TABLE silver_base_region ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_order_detail 添加列
ALTER TABLE silver_order_detail ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_sku_info 添加列
ALTER TABLE silver_sku_info ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_spu_info 添加列
ALTER TABLE silver_spu_info ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- silver_user_info 添加列
ALTER TABLE silver_user_info ADD COLUMNS (
    source_file STRING,
    load_timestamp TIMESTAMP,
    update_timestamp TIMESTAMP
);

-- %%
select * from silver_base_category1

-- %%
-- silver_user_info 添加列
ALTER TABLE silver_user_info ADD COLUMNS (
    is_latest BOOLEAN
);

update silver_user_info set is_latest = true;

select * from silver_user_info

-- %%
--保存到glod层（Delta格式,内部表）

CREATE TABLE IF NOT EXISTS gold_dim_date
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/gold/dim_date'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',  -- 开启，因为每天全量写入
    'delta.autoOptimize.autoCompact' = 'true',
    'delta.dataSkippingNumIndexedCols' = '10',  -- 提高数据跳过效率
    -- 全量表可以保留更短的日志
    'delta.logRetentionDuration' = 'interval 7 days'
)
AS
WITH date_series AS (
    SELECT explode(sequence(
        to_date('2020-01-01'), 
        to_date('2030-12-31'), 
        interval 1 day
    )) as date
)
SELECT 
    -- 代理键
    CAST(date_format(date, 'yyyyMMdd') AS INT) as date_key,
    
    -- 日期属性
    date as full_date,
    YEAR(date) as year,
    QUARTER(date) as quarter,
    MONTH(date) as month,
    DAY(date) as day,
    
    -- 周信息
    WEEKOFYEAR(date) as week_of_year,
    DAYOFWEEK(date) as day_of_week,
    
    -- 业务标记
    CASE WHEN DAYOFWEEK(date) IN (1,7) THEN 1 ELSE 0 END as is_weekend,
    CASE WHEN MONTH(date) = 12 AND DAY(date) = 25 THEN 1 ELSE 0 END as is_christmas,
    CURRENT_TIMESTAMP() as load_time
    
FROM date_series;


CREATE TABLE adhyivy.default.gold_dim_province 
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/gold/dim_province'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',  -- 开启，因为每天全量写入
    'delta.autoOptimize.autoCompact' = 'true',
    'delta.dataSkippingNumIndexedCols' = '10',  -- 提高数据跳过效率
    -- 全量表可以保留更短的日志
    'delta.logRetentionDuration' = 'interval 7 days'
)
AS
select
    province.id,
    province.name,
    province.area_code,
    province.iso_code,
    province.iso_3166_2,
    region_id,
    region_name,
    CURRENT_TIMESTAMP() as load_time
from
(
    select
        id,
        name,
        region_id,
        area_code,
        iso_code,
        iso_3166_2
    from silver_base_province
)province
left join
(
    select
        id,
        region_name
    from silver_base_region
)region
on province.region_id=region.id;


CREATE TABLE adhyivy.default.gold_dim_sku 
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/gold/dim_sku'
TBLPROPERTIES (
    'delta.autoOptimize.optimizeWrite' = 'true',  -- 开启，因为每天全量写入
    'delta.autoOptimize.autoCompact' = 'true',
    'delta.dataSkippingNumIndexedCols' = '10',  -- 提高数据跳过效率
    -- 全量表可以保留更短的日志
    'delta.logRetentionDuration' = 'interval 7 days'
)
AS
with
sku as
(
    select
        id,
        price,
        sku_name,
        sku_desc,
        weight,
        is_sale,
        spu_id,
        category3_id,
        tm_id,
        create_time
    from silver_sku_info
),
spu as
(
    select
        id,
        spu_name
    from silver_spu_info
),
c3 as
(
    select
        id,
        name,
        category2_id
    from silver_base_category3
),
c2 as
(
    select
        id,
        name,
        category1_id
    from silver_base_category2
),
c1 as
(
    select
        id,
        name
    from silver_base_category1
),
tm as
(
    select
        id,
        tm_name
    from silver_base_trademark
)
select
    sku.id,
    sku.price,
    sku.sku_name,
    sku.sku_desc,
    sku.weight,
    sku.is_sale,
    sku.spu_id,
    spu.spu_name,
    sku.category3_id,
    c3.name,
    c3.category2_id,
    c2.name,
    c2.category1_id,
    c1.name,
    sku.tm_id,
    tm.tm_name,
    CURRENT_TIMESTAMP() as load_time
from sku
left join spu on sku.spu_id=spu.id
left join c3 on sku.category3_id=c3.id
left join c2 on c3.category2_id=c2.id
left join c1 on c2.category1_id=c1.id
left join tm on sku.tm_id=tm.id
;


CREATE TABLE adhyivy.default.gold_dim_user_scd2 
USING DELTA
LOCATION 'abfss://bronze@sahyivy.dfs.core.windows.net/gold/dim_user_scd2'
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true',  -- SCD2需要变更数据追踪
    'delta.autoOptimize.optimizeWrite' = 'true',  -- 增量写入优化
    'delta.autoOptimize.autoCompact' = 'true',    -- 自动合并小文件
    'delta.logRetentionDuration' = 'interval 30 days',  -- 保留30天日志
    'delta.deletedFileRetentionDuration' = 'interval 7 days'  -- 7天文件清理
)
AS
select
    id          ,
    login_name            ,
    nick_name             ,
    passwd                ,
    name                  ,
    phone_num             ,
    email                 ,
    head_img              ,
    user_level            ,
    birthday              ,
    gender                ,
    create_time           ,
    operate_time          ,
    status                ,
    -- source_file           ,
    update_timestamp       valid_from ,
    CAST('9999-12-31' AS DATE) as valid_to,
    is_latest                               ,
    CURRENT_TIMESTAMP() as load_time,
    CURRENT_TIMESTAMP() as update_time
from
silver_user_info;


--建表SQL
CREATE TABLE adhyivy.default.gold_fact_sales
USING DELTA
LOCATION 'abfss://bronze@adls.dfs.core.windows.net/gold/fact_sales'
TBLPROPERTIES (
    'delta.enableChangeDataFeed' = 'true',  -- SCD2需要变更数据追踪
    'delta.autoOptimize.optimizeWrite' = 'true',  -- 增量写入优化
    'delta.autoOptimize.autoCompact' = 'true',    -- 自动合并小文件
    'delta.logRetentionDuration' = 'interval 30 days',  -- 保留30天日志
    'delta.deletedFileRetentionDuration' = 'interval 7 days'  -- 7天文件清理
)
AS
select
    od.id,
    od.order_id,
    user_id,
    sku_id,
    province_id,
    to_number(to_char(od.create_time, 'yyyyMMdd'),99999999) as date_id,
    od.create_time,
    sku_num,
    order_price,
    sku_num * order_price split_original_amount,
    nvl(split_activity_amount,0.0) split_activity_amount,
    nvl(split_coupon_amount,0.0) split_coupon_amount,
    split_total_amount,
    case when od.update_timestamp < oi.update_timestamp then oi.update_timestamp else od.update_timestamp end as ods_max_update_time,
    CURRENT_TIMESTAMP() as load_time,
    CURRENT_TIMESTAMP() as update_time
from
    adhyivy.default.silver_order_detail od
    left join adhyivy.default.silver_orders_info oi on od.order_id = oi.id
;
